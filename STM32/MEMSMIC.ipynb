# %% [markdown]
# # MEMSMIC: Spectral Analysis
#
# Date: 2023/09/17
#
# Environment: in a room with a mix of hair dryer noise and speech and human conversation

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("teraterm_MEMSMIC_20230917.log", delimiter='\t', skiprows=4)
df
# Out:
#         Freq         Mag    Mag(dB)
# 0        0.0    1.000000   0.000000
# 1        9.5    1.000000   0.000000
# 2       19.1    1.000000   0.000000
# 3       28.6    1.000000   0.000000
# 4       38.1    1.000000   0.000000
# ...      ...         ...        ...
# 1019  9717.8  510.567719  27.080534
# 1020  9727.4  483.060425  26.840015
# 1021  9736.9  501.812134  27.005413
# 1022  9746.4  548.832703  27.394400
# 1023  9756.0  461.693756  26.643541
#
# [1024 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(df.Freq, df.Mag)
ax.set_xlabel('Frequency(Hz)')
ax.set_ylabel('Amplitude')
ax.set_title('Spectrogram')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(df.Freq, df['Mag(dB)'])
ax.set_xlabel('Frequency(Hz)')
ax.set_ylabel('Magnitude(dB)')
ax.set_title('Spectrogram')
plt.show()

# %%
fig.savefig('doc/spectrogram_room.png',  bbox_inches='tight')
